# %% [markdown]
# <h1>Exploratory Data Analysis on Bank of Botswana data for Inflation Rates, Exchange Rates, and Prices</h1>

# %% [markdown]
# <h3>Introduction</h3>

# %% [markdown]
# This is the second notebook for the project for predicting inflation rate using data collected from Bank of Botswana. The first notebook was about collecting the data and cleaning it by dealing with various issues such as missing values.
#
# This notebook will take a look at various patterns in the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Bringing the cleaned data into the notebook

# %%
df = pd.read_csv('Economic_Data_BOB')

# %%
df.head()
# Out:
#          date  7 Day Bobc  1 Month BoBC     CHN     EUR     GBP     USD  \
# 0  2022-09-02        2.65          2.43  0.5340  0.0775  0.0670  0.0772
# 1  2022-09-01        2.65          2.43  0.5359  0.0774  0.0670  0.0775
# 2  2022-08-31        2.65          2.43  0.5395  0.0779  0.0669  0.0782
# 3  2022-08-30        2.15          2.43  0.5420  0.0783  0.0669  0.0783
# 4  2022-08-29        2.15          2.43  0.5405  0.0785  0.0669  0.0780
#
#       SDR    YEN     ZAR   CPI  CPIT  CPIXA
# 0  0.0595  10.84  1.3355  12.7  10.3    6.6
# 1  0.0596  10.80  1.3333  12.7  10.3    6.6
# 2  0.0599  10.82  1.3234  12.7  10.3    6.6
# 3  0.0601  10.85  1.3191  12.7  10.3    6.6
# 4  0.0600  10.83  1.3216  12.7  10.3    6.6

# %%
df.tail(10)
# Out:
#             7 Day Bobc  1 Month BoBC  CHN       EUR       GBP       USD  \
# date
# 2009-07-01       11.96           0.0  0.0  0.100726  0.089723  0.140546
# 2009-08-01       11.96           0.0  0.0  0.100726  0.089723  0.140546
# 2009-02-01       11.96           0.0  0.0  0.100726  0.089723  0.140546
# 2009-03-01       11.96           0.0  0.0  0.100726  0.089723  0.140546
# 2008-11-01       11.96           0.0  0.0  0.100726  0.089723  0.140546
# 2008-05-01       11.96           0.0  0.0  0.100726  0.089723  0.140546
# 2008-06-01       11.96           0.0  0.0  0.100726  0.089723  0.140546
# 2008-07-01       11.96           0.0  0.0  0.100726  0.089723  0.140546
# 2008-03-01       11.96           0.0  0.0  0.100726  0.089723  0.140546
# 2008-01-01       11.96           0.0  0.0  0.100726  0.089723  0.140546
#
#                  SDR      YEN       ZAR   CPI  CPIT  CPIXA
# date
# 2009-07-01  0.091038  13.1275  1.175903   6.0   7.4   14.2
# 2009-08-01  0.091038  13.1275  1.175903   6.1   6.9   13.4
# 2009-02-01  0.091038  13.1275  1.175903  11.7  10.2   15.8
# 2009-03-01  0.091038  13.1275  1.175903  11.7  10.6   15.8
# 2008-11-01  0.091038  13.1275  1.175903  15.0  13.6   15.5
# 2008-05-01  0.091038  13.1275  1.175903  12.1  11.0    9.1
# 2008-06-01  0.091038  13.1275  1.175903  14.5  12.5    9.8
# 2008-07-01  0.091038  13.1275  1.175903  15.0  12.7   11.1
# 2008-03-01  0.091038  13.1275  1.175903   9.8   9.7    8.9
# 2008-01-01  0.091038  13.1275  1.175903   8.4   7.9    7.2

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.set_index('date', inplace=True)

# %%
df = df.loc['2008-01-01':'2022-09-02']

# %%
df.head(20)
# Out:
#             7 Day Bobc  1 Month BoBC     CHN     EUR     GBP     USD     SDR  \
# date
# 2022-09-02        2.65          2.43  0.5340  0.0775  0.0670  0.0772  0.0595
# 2022-09-01        2.65          2.43  0.5359  0.0774  0.0670  0.0775  0.0596
# 2022-08-31        2.65          2.43  0.5395  0.0779  0.0669  0.0782  0.0599
# 2022-08-30        2.15          2.43  0.5420  0.0783  0.0669  0.0783  0.0601
# 2022-08-29        2.15          2.43  0.5405  0.0785  0.0669  0.0780  0.0600
# 2022-08-26        2.15          2.43  0.5393  0.0788  0.0665  0.0785  0.0602
# 2022-08-25        2.15          2.43  0.5379  0.0783  0.0662  0.0785  0.0600
# 2022-08-24        2.15          2.43  0.5359  0.0784  0.0660  0.0779  0.0598
# 2022-08-23        2.15          2.44  0.5360  0.0786  0.0664  0.0779  0.0599
# 2022-08-22        2.15          2.44  0.5348  0.0779  0.0661  0.0782  0.0598
# 2022-08-19        2.15          2.44  0.5354  0.0779  0.0659  0.0785  0.0599
# 2022-08-18        2.15          2.44  0.5382  0.0778  0.0657  0.0791  0.0601
# 2022-08-17        2.15          2.44  0.5415  0.0785  0.0659  0.0798  0.0605
# 2022-08-16        2.15          2.44  0.5434  0.0785  0.0662  0.0798  0.0606
# 2022-08-15        2.15          2.44  0.5436  0.0784  0.0663  0.0803  0.0607
# 2022-08-12        2.15          2.44  0.5426  0.0781  0.0660  0.0805  0.0607
# 2022-08-11        2.15          2.44  0.5430  0.0783  0.0660  0.0806  0.0608
# 2022-08-10        2.15          2.44  0.5372  0.0778  0.0658  0.0795  0.0602
# 2022-08-09        2.15          2.44  0.5369  0.0779  0.0658  0.0794  0.0602
# 2022-08-08        2.15          2.44  0.5355  0.0777  0.0655  0.0791  0.0600
#
#               YEN     ZAR   CPI  CPIT  CPIXA
# date
# 2022-09-02  10.84  1.3355  12.7  10.3    6.6
# 2022-09-01  10.80  1.3333  12.7  10.3    6.6
# 2022-08-31  10.82  1.3234  12.7  10.3    6.6
# 2022-08-30  10.85  1.3191  12.7  10.3    6.6
# 2022-08-29  10.83  1.3216  12.7  10.3    6.6
# 2022-08-26  10.75  1.3176  12.7  10.3    6.6
# 2022-08-25  10.72  1.3225  12.7  10.3    6.6
# 2022-08-24  10.66  1.3294  12.7  10.3    6.6
# 2022-08-23  10.70  1.3278  12.7  10.3    6.6
# 2022-08-22  10.71  1.3302  12.7  10.3    6.6
# 2022-08-19  10.70  1.3279  12.7  10.3    6.6
# 2022-08-18  10.69  1.3234  12.7  10.3    6.6
# 2022-08-17  10.73  1.3111  12.7  10.3    6.6
# 2022-08-16  10.64  1.3105  12.7  10.3    6.6
# 2022-08-15  10.70  1.3066  12.7  10.3    6.6
# 2022-08-12  10.74  1.3071  12.7  10.3    6.6
# 2022-08-11  10.72  1.3057  12.7  10.3    6.6
# 2022-08-10  10.73  1.3212  12.7  10.3    6.6
# 2022-08-09  10.73  1.3218  12.7  10.3    6.6
# 2022-08-08  10.72  1.3270  12.7  10.3    6.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3771 entries, 2022-09-02 to 2008-01-01
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   7 Day Bobc    3771 non-null   float64
#  1   1 Month BoBC  3771 non-null   float64
#  2   CHN           3771 non-null   float64
#  3   EUR           3771 non-null   float64
#  4   GBP           3771 non-null   float64
#  5   USD           3771 non-null   float64
#  6   SDR           3771 non-null   float64
#  7   YEN           3771 non-null   float64
#  8   ZAR           3771 non-null   float64
#  9   CPI           3771 non-null   float64
#  10  CPIT          3771 non-null   float64
#  11  CPIXA         3771 non-null   float64
# dtypes: float64(12)
# memory usage: 383.0 KB

# %% [markdown]
# As expected, there are no missing values. A quick look at summary statistics:

# %%
df.describe()
# Out:
#         7 Day Bobc  1 Month BoBC          CHN          EUR          GBP  \
# count  3771.000000   3771.000000  3771.000000  3771.000000  3771.000000
# mean      4.194962      0.021199     0.240576     0.090499     0.076469
# std       3.791778      0.225670     0.302073     0.011229     0.010232
# min       0.730000      0.000000     0.000000     0.071800     0.058800
# 25%       1.290000      0.000000     0.000000     0.082200     0.067600
# 50%       3.010000      0.000000     0.000000     0.086700     0.074200
# 75%       6.570000      0.000000     0.599650     0.100726     0.084800
# max      13.130000      2.440000     0.678700     0.117500     0.100400
#
#                USD          SDR          YEN          ZAR          CPI  \
# count  3771.000000  3771.000000  3771.000000  3771.000000  3771.000000
# mean      0.113843     0.077152    11.440367     1.234126     5.906046
# std       0.024041     0.017314     1.658064     0.114577     3.431899
# min       0.077200     0.059500     8.690000     1.025800     0.900000
# 25%       0.092900     0.067000    10.210000     1.141650     3.100000
# 50%       0.104800     0.072800    11.100000     1.236300     4.600000
# 75%       0.138200     0.089450    12.340000     1.324050     8.200000
# max       0.167700     0.821000    18.210000     1.549000    15.100000
#
#               CPIT        CPIXA
# count  3771.000000  3771.000000
# mean      5.569451     5.716309
# std       3.065374     3.178861
# min       1.000000     1.600000
# 25%       2.900000     3.300000
# 50%       4.200000     5.300000
# 75%       7.900000     7.000000
# max      13.600000    16.400000

# %% [markdown]
# <h3>Exploratory Data Analysis - Data Visualization</h3>

# %% [markdown]
# The target variable here is inflation rate. The goal to the project is to see whether we can predict inflation rate based on the other variables. Below, we shall plot a few graphs to see if there is any correlation with inflation rate.
#
# Firstly, we shall look at currencies and plot them against inflation rate. Our Inflation rate will be the CPI since it is widely accepted as inflation rate.

# %%
print('China Yuan: ' + str(df['CPI'].corr(df['CHN'])))
print('Euro: ' + str(df['CPI'].corr(df['EUR'])))
print('British Pound: ' + str(df['CPI'].corr(df['GBP'])))
print('US Dollar: ' + str(df['CPI'].corr(df['USD'])))
print('Special Drawing Rights: ' + str(df['CPI'].corr(df['SDR'])))
print('Japanese Yen: ' + str(df['CPI'].corr(df['YEN'])))
print('South African Rand: ' + str(df['CPI'].corr(df['ZAR'])))
# Out:
# China Yuan: -0.33564989847939714
# Euro: 0.43209037875969547
# British Pound: 0.3733959511319969
# US Dollar: 0.5299863973171306
# Special Drawing Rights: 0.3675758968414081
# Japanese Yen: 0.5118651086157803
# South African Rand: -0.4289183619093807

# %% [markdown]
# The US Dollar has the highest correlation coefficient out of all the currencies with 0.599 followed by the YEN with 0.549. The scatter plot below does show some correlation.

# %%
plt.scatter(df['CPI'], df['USD'])

# %% [markdown]
# Next we explore correlation between inflation and interest rates.

# %%
print('7 Day Bobc: ' + str(df['CPI'].corr(df['7 Day Bobc'])))
print('1 Month BoBC: ' + str(df['CPI'].corr(df['1 Month BoBC'])))
# Out:
# 7 Day Bobc: 0.6584285255025644
# 1 Month BoBC: 0.18601032900879408

# %% [markdown]
# The 7 Day Bobc has a significantly high correlation with inflation. It could likely be a great predictor for inflation.

# %%
plt.scatter(df['CPI'], df['7 Day Bobc'])

# %% [markdown]
# As can be seen above, it is pretty clear that there is a fairly strong correlation between CPI and the 7 day Bobc.

# %% [markdown]
# The next step is to plot a few time series to see whether there is any seasonality in the data.

# %%
plt.scatter(df.index, df['CPI'])

# %% [markdown]
# The scatterplot above shows that CPI was extremely high in 2008 (Possibly due to the recession) although prices were dropping rapidly. There was a small spike in 2012 and then prices dropped significantly and stayed there until 2020. Since 2020, prices have shot up again. Probably due to the covid pandemic and the war between russia and Ukraine. Lets see how the value of USD varied in comparison.

# %%
plt.scatter(df.index, df['USD'])

# %% [markdown]
# The value of the USD in comparison with the pula has been consistently dropping since 2008.

# %%
plt.figure(figsize=(20,20))
sns.boxplot(y=df['CPI'], x=df.index.year)
# Out:
# <AxesSubplot:xlabel='date', ylabel='CPI'>

# %% [markdown]
# CPI is most volatile in 2021. Ranging from around 2.5 to 10.5. It is lowest in 2020 and highest in 2008. 2022 is the second highest.
